# %% [markdown]
# # Working With DataSets  06/08/2025

# %%
import pandas as pd
import numpy as np

# %%
# !pip install xlrd

# Used because Pandas needs xlrd (or another engine) to read older Excel files (.xls)
# Out:
# ...
#   Obtaining dependency information for xlrd from https://files.pythonhosted.org/packages/1a/62/c8d562e7766786ba6587d09c5a8ba9f718ed3fa8af7f4553e8f91c36f302/xlrd-2.0.2-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/96.6 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/96.6 kB ? eta -:--:--
#    ------------ --------------------------- 30.7/96.6 kB 325.1 kB/s eta 0:00:01
#    ---------------------------------------- 96.6/96.6 kB 784.7 kB/s eta 0:00:00
# ...

# %%
titanic = pd.read_excel(r"C:\Users\Dell\Downloads\Datasets PYTHON 62\Datasets\Titanic_Survival_Train.xls",
                        header = 0, index_col = 0)

titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# Helps to display all columns as well as rows while handling the data

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# Show all columns when displaying a DataFrame
# By Default, Pandas hides extra columns and shows ... if there are too many
# None means no limit

# %% [markdown]
# # Data Preprocessing
#
# Data Preprocessing is a crucial step in the data preparation process for analysis or modeling. It involves a series of operations and techniques applied to raw or collected data to transform it into a format that is suitable analysis. the main goals of data processing are to clean the data, handle missing values, deal with outliers, and prepare the data in a way that makes it ready for modeling or analysis.
#
# # 1.Data Cleaning:-
#
# - Removing or correcting inaccurate or inconsistent data.
# - Handling duplicate records or entries.
# - Standardizing data formats and values.
#
#
# # 2.Handling Missing Data:-
#
# - Identifying and handling missing values, which can involve imputation (replacing missing values with estimated values) or removal of rows or solumns with excessive missing data.
#
#
# # 3. Data Transformation:-
#
# - Encoding categorical variables into numerical format, often using techniques like one-hot encoding or label encoding.
# - Scaling or normalizing numerical features to bring them to a common scale.
# - Logarithmic or power transformations to address data skewness.
#
#
# # 4. Handling Outliers:-
#
# - Identifying and addressing outliers, which can involve removing or transforming extreme values.
#
#
# # 5. Feature Engineering:-
#
# - Creating new features based on domain knowledge or insights from the data
# - Reducing dimensionality through techniques like Principal Component Analysis(PCA)
#
#
# # 6. Data Reduction:-
#
# - Reducing the size of the dataset while preserving its essential characteristics, often through techniques like sampling or aggregation.
#
#
# # 7. Data Integration:-
#
# - Combining data from multiple sources into a single dataset.
#
#
# # 8. Data Formatting:-
#
# - Ensuring that the data is in the correct data types(eg:- dates are in date format) and has consistent units.
#
#
# # 9. Data Splitting:-
#
# - Splitting the data into training, validation, and test sets for machine learning tasks.
#
#
# # 10. Handling Imbalanced Data:-
#
# - Addressing class Imbalance in Classification problems through techniques like oversampling, undersampling, or using synthetic data generation methods.

# %% [markdown]
# # What is EDA
#
# EDA stands for Exploratory Data Analysis. It is an approach to data analysis that focuses on summarizing and visualizing data to better understand its underlying structure, patterns, and relationships. EDA is typically one of the first steps in the data analysis process and is used to gain insights into the data before more advanced statistical or machine learning techniques are applied.
#
# Key objectives of EDA include:
#
# **1. Data Summarization:
# - EDA involves calculating summary statistics such as mean, median, variance, and percentiles to get a basic understanding of the data's central tendencies and spread.
#
# **2. Data Visualization:
# - Visualization techniques, such as histograms, scatter plots, box plots, and heatmaps, are used to visually represent the data. These visualizations can reveal patterns, trends, outliers, and potential issues in the data.
#
# **3. Data Cleaning:
# - EDA often highlights missing data, duplicate records, and outliers, which may require data cleaning or preprocessing before further analysis.
#
# **4. Pattern Discovery:
# - Analysts use EDA to discover patterns, correlations, and relationships within the data. This can involve identifying clusters, trends, or anomalies that may inform subsequent analysis.
#
# **5. Hypothesis Generation:
# - EDA can help generate hypotheses about the data, which can be tested using statistical methods or machine learning
#
# **6. Data Exploration:-
# - EDA encourages the exploration of data from various angles and perspectives to gain a comprehensive understanding of its characteristics.
#
#
# EDA is a crucial step in the data analysis process as it helps analysts

# %%
# for getting first 5 rows from the dataset(most commonly used function)

titanic.head()

# Input values
titanic.head(15)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# ...

# %%
# For last 5 values from data

titanic.tail()
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 887            male  27.0      0      0      211536  13.00   NaN        S
# 888          female  19.0      0      0      112053  30.00   B42        S
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890            male  26.0      0      0      111369  30.00  C148        C
# 891            male  32.0      0      0      370376   7.75   NaN        Q

# %%
# The shape returns the number of rows and columns of the DataFrame

titanic.shape
# Out:
# (891, 11)

# %%
# The info() method prints information about the Dataframe.
# The information contains the number of columns, column labls, column data types,
# memory usage, range index, and the number of cells in each column (non-null values)


titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
# the dtypes property returns data type of each column in the dataframe
titanic.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %% [markdown]
# The describe() method returns description of the data in the DataFrame.
#
# If the DataFrame contains numerical data, the description contains these information for each column:
#
# count - The number of not-empty values
# mean - The average (mean) value
# std - The standard deviation. (distance for mean)
# min - The minimum value
# 25% - The 25% percentile (What value is in 25%)
# 50% - The 50% percentile (Value in mid point)
# 75% - The 75% percentile
# max - The maximum value
#
# By default all the columns which contains numerical data are included in the output. To consider or get the description of the object/ string data you have to provide "include=all" as an argument in the method

# %%
# describe = descriptive statistics
titanic.describe()
# supervised either 0 or 1 , mean will not make sence hense std also want make sense
# pclass - passanger class 1,2,3
# age min not making sense so we can round off- 4months
# sibsp - siblings and spouses
# parch - parent and children
# fare  - price
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.describe(include = "all")
# Out:
#           Survived      Pclass                     Name   Sex         Age  \
# count   891.000000  891.000000                      891   891  714.000000
# unique         NaN         NaN                      891     2         NaN
# top            NaN         NaN  Braund, Mr. Owen Harris  male         NaN
# freq           NaN         NaN                        1   577         NaN
# mean      0.383838    2.308642                      NaN   NaN   29.699118
# std       0.486592    0.836071                      NaN   NaN   14.526497
# min       0.000000    1.000000                      NaN   NaN    0.420000
# 25%       0.000000    2.000000                      NaN   NaN   20.125000
# 50%       0.000000    3.000000                      NaN   NaN   28.000000
# 75%       1.000000    3.000000                      NaN   NaN   38.000000
# max       1.000000    3.000000                      NaN   NaN   80.000000
#
#              SibSp       Parch    Ticket        Fare    Cabin Embarked
# ...

# %%
titanic.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
titanic.Sex.describe()
# Out:
# count      891
# unique       2
# top       male
# freq       577
# Name: Sex, dtype: object

# %%
titanic.Age.mean()
# Out:
# 29.69911764705882

# %%
titanic.Age.median()
# Out:
# 28.0

# %%
titanic.Age.quantile(0.30)

# Calculates the 30th percentile (value below which 30% of the data falls)
# Out:
# 22.0

# %%
titanic.Age.mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
# Value COunt:- Value count is used to check the frequency distribution of categorical variables in Pandas

titanic.Cabin.value_counts()
# value_counts() - How many times does each value occurs
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %% [markdown]
# # Matplotlib
#
# We use Matplotlib because it's the foundation plotting library in Python for visualizing data.
# Helps see trends, patterns, and outliers
# Can create line, bar, scatter, histogram, boxplot, pie chart, etc

# %%
# titanic.boxplot()

import matplotlib.pyplot as plt   # pyplot provides functions to make different graphs (Line, bar, scatter, pie, etc)
titanic.boxplot(column="Age")    # Particularly implemented
plt.show()  # To show the visual


# Majorly use numeric data where mean and std can be calculated
# Most widely used to observe the outliers in the dataset
# min and max is plotted

# %%
titanic.Survived.value_counts().plot(kind='bar')
plt.show()

# .plot(kind='bar')
# Plots the counts as a bar chart
# kind='bar' tells Pandas/Matplotlib to use vertical bars

# %%
titanic.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
titanic.Embarked.nunique()
# Out:
# 3

# %%
titanic.Age.std()
# Out:
# 14.526497332334044

# %% [markdown]
# # Data will be of 3 types
#
# 1) Categorical
# category has 2 types:-
#
# a) Nominal(Unordered in nature) eg(Names of flowers can be in any order)
# b) Ordinal(Ordered in nature) eg(good, better, best) should be in order
#
# 2) Discreate continuous - Numerical(Finite number/ countable) (phone no.) --> describe()
#
# 3) Continuous - Numeric -(range of value like fare price can be in decimals)
#
# **Describe() --> Numerical,
# **Categorical --> value_count(),crosstab(),unique()

# %%
titanic.Sex.value_counts().plot(kind='pie')
plt.show()

# %%
titanic.Sex.value_counts()/len(titanic)*100
# Calculating the percentage of males and females in the Titanic dataset

# len(titanic)- gets the total number of rows in the DataFrame
# * 100 - converts proportions to percentages
# Out:
# Sex
# male      64.758698
# female    35.241302
# Name: count, dtype: float64

# %%
# ?pd.crosstab
# Summerize the relationship between two(or more) categorical variables in a table form like a quick pivot table

# %%
# Allows to compare two categorical variables
pd.crosstab(titanic['Pclass'],titanic['Survived'])

# Pclass = Passenger class
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
pd.crosstab(titanic['Sex'],titanic['Survived'])
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
pd.crosstab(titanic['Pclass'],[titanic['Survived'],  # 1st will give index - Pclass then col survived
                               titanic['Sex']])     # col 1 more

# This will give the total of 0's & 1's and 1st,2nd,3rd class passenger
# and total = 891 1st class 216
# Out:
# Survived      0           1
# Sex      female male female male
# Pclass
# 1             3   77     91   45
# 2             6   91     70   17
# 3            72  300     72   47

# %%
# Subsetting the DataFrame
# 1 Index position wise --> loc, iloc
# 2 Conditional Filtering --> condition

# %%
titanic.loc[31:40,["Pclass","Age"]]
# Value from 31 to 40 and skip 2nd value from passenger id as we already set it as index
# Out:
#              Pclass   Age
# PassengerId
# 31                1  40.0
# 32                1   NaN
# 33                3   NaN
# 34                2  66.0
# 35                1  28.0
# 36                1  42.0
# 37                3   NaN
# 38                3  21.0
# 39                3  18.0
# 40                3  14.0

# %%
titanic.loc[25:40:2,["Pclass","Age"]]
# Out:
#              Pclass   Age
# PassengerId
# 25                3   8.0
# 27                3   NaN
# 29                3   NaN
# 31                1  40.0
# 33                3   NaN
# 35                1  28.0
# 37                3   NaN
# 39                3  18.0

# %%
titanic.loc[25:40:2,"Pclass":"Fare"] # Starting from Pclass till Fare
# Out:
#              Pclass                                Name     Sex   Age  SibSp  \
# PassengerId
# 25                3       Palsson, Miss. Torborg Danira  female   8.0      3
# 27                3             Emir, Mr. Farred Chehab    male   NaN      0
# 29                3       O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 31                1            Uruchurtu, Don. Manuel E    male  40.0      0
# 33                3            Glynn, Miss. Mary Agatha  female   NaN      0
# 35                1             Meyer, Mr. Edgar Joseph    male  28.0      1
# 37                3                    Mamee, Mr. Hanna    male   NaN      0
# 39                3  Vander Planke, Miss. Augusta Maria  female  18.0      2
#
#              Parch    Ticket     Fare
# PassengerId
# 25               1    349909  21.0750
# 27               0      2631   7.2250
# 29               0    330959   7.8792
# 31               0  PC 17601  27.7208
# 33               0    335677   7.7500
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 115.8+ KB

# %%
# Subsetting the DataFrame
titanic.iloc[21:100,[3,6,1,0]]
# Out:
#                 Sex  Parch  Pclass  Survived
# PassengerId
# 22             male      0       2         1
# 23           female      0       3         1
# 24             male      0       1         1
# 25           female      1       3         0
# 26           female      5       3         1
# ...             ...    ...     ...       ...
# 96             male      0       3         0
# 97             male      0       1         0
# 98             male      1       1         1
# 99           female      1       2         1
# 100            male      0       2         0
#
# [79 rows x 4 columns]

# %%
# Filtering
# Passenger who have age greater than 60 & is male

df_filtering = titanic[(titanic["Sex"]=="male") & (titanic["Fare"] > 100)]
df_filtering
# Out:
#              Survived  Pclass                                        Name  \
# PassengerId
# 28                  0       1              Fortune, Mr. Charles Alexander
# 119                 0       1                    Baxter, Mr. Quigg Edmond
# 306                 1       1              Allison, Master. Hudson Trevor
# 333                 0       1                   Graham, Mr. George Edward
# 374                 0       1                         Ringhini, Mr. Sante
# 378                 0       1                   Widener, Mr. Harry Elkins
# 391                 1       1                  Carter, Mr. William Ernest
# 439                 0       1                           Fortune, Mr. Mark
# 506                 0       1  Penasco y Castellana, Mr. Victor de Satode
# 528                 0       1                          Farthing, Mr. John
# 545                 0       1                  Douglas, Mr. Walter Donald
# ...

# %%
df2 = titanic[(titanic['Age'] < 60) & (titanic['Sex']== 'male') & (titanic['Survived']== 1)]
df2
# Out:
#              Survived  Pclass                             Name   Sex    Age  \
# PassengerId
# 22                  1       2            Beesley, Mr. Lawrence  male  34.00
# 24                  1       1     Sloper, Mr. William Thompson  male  28.00
# 75                  1       3                    Bing, Mr. Lee  male  32.00
# 79                  1       2    Caldwell, Master. Alden Gates  male   0.83
# 82                  1       3      Sheerlinck, Mr. Jan Baptist  male  29.00
# ...               ...     ...                              ...   ...    ...
# 832                 1       2  Richards, Master. George Sibley  male   0.83
# 839                 1       3                  Chip, Mr. Chang  male  32.00
# 858                 1       1           Daly, Mr. Peter Denis   male  51.00
# 870                 1       3  Johnson, Master. Harold Theodor  male   4.00
# 890                 1       1            Behr, Mr. Karl Howell  male  26.00
#
# ...

# %%
df2 = titanic.loc[(titanic['Age'] < 60) & (titanic['Sex']== 'male') & 
                  (titanic['Survived']== 1),['Age','Pclass','Survived']]  # loc condition satisfied at the end

# df2   # I will get all the values as per condition
df2.head(15)
# Out:
#                Age  Pclass  Survived
# PassengerId
# 22           34.00       2         1
# 24           28.00       1         1
# 75           32.00       3         1
# 79            0.83       2         1
# 82           29.00       3         1
# 98           23.00       1         1
# 126          12.00       3         1
# 128          24.00       3         1
# 147          27.00       3         1
# 166           9.00       3         1
# 184           1.00       2         1
# 188          45.00       1         1
# 194           3.00       2         1
# 205          18.00       3         1
# 208          26.00       3         1

# %% [markdown]
# # Feature Engineering
#
# Feature engineering (choosing important col and drop rest)
#
# 1) Client approch From the data what is important for client (we can ask the clients whatever client syas need to be added)
#
# 2) domain Knowledge (if teh client doesnt tell you about the data)
#
# 3) Singularity Single data in a col Eg one country (we need less dimensions so we cam remove)
#
# 4) High no of missing value eg pin code missing we cant remove the null values as data loss will be a concern
#
# 5) cardinality high No of category Like gender and the sub category We will see if it is important or not, if not
#
# important we will drop, if important we can devide into sub category
#
#
# 6) Then we have ML approch
#
#
# ### Data Cleaning
#
# Data cleaning means fixing messy data in your data set. As the machine learning model never accepts messy data, so before model building you have to clean your messy data.
#
# Messy data could be:
#
# Empty cells
#
# Data in wrong format
#
# Wrong data
#
# Duplicates

# %%
#Treating the missing value
# isnull Checks for missing values (NaN or None) in a DataFrame or series

# titanic.isnull()
titanic.isnull().sum    # to check the sum

# Whereever there is true there is a missing value
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of              Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# PassengerId
# 1               False   False  False  False  False  False  False   False
# 2               False   False  False  False  False  False  False   False
# 3               False   False  False  False  False  False  False   False
# 4               False   False  False  False  False  False  False   False
# 5               False   False  False  False  False  False  False   False
# ...               ...     ...    ...    ...    ...    ...    ...     ...
# 887             False   False  False  False  False  False  False   False
# 888             False   False  False  False  False  False  False   False
# 889             False   False  False  False   True  False  False   False
# 890             False   False  False  False  False  False  False   False
# 891             False   False  False  False  False  False  False   False
#
# ...

# %%
# Treatting the missing values

# To check the missing %

titanic.isnull().sum()/len(titanic)*100

# Cabin has 77% data missing we can drop it
# Out:
# Survived     0.000000
# Pclass       0.000000
# Name         0.000000
# Sex          0.000000
# Age         19.865320
# SibSp        0.000000
# Parch        0.000000
# Ticket       0.000000
# Fare         0.000000
# Cabin       77.104377
# Embarked     0.224467
# dtype: float64

# %%
# isna 
# Checks for missing values (Nan or None) just like isnull()
# It is basically an alias (alternative name) for isnull()

titanic.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
# Check missing values in any specific col

print(titanic[['Age','Cabin','Pclass']].isnull().sum())
# Out:
# Age       177
# Cabin     687
# Pclass      0
# dtype: int64

# %%
# It will give descending order

print(titanic.isnull().sum().sort_values(ascending = False))

# .sort_values(ascending=False)- Sorts the result in descending order of missing values
# ascending=False - highest number of Nan values at the top
# Out:
# Cabin       687
# Age         177
# Embarked      2
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# dtype: int64

# %%
# drop vs dropna
# drop()
# Purpose - Remove rows or columns by label or index position
# Focus - Works on specific labels/index, not based on missing values


# dropna()
# Purpose - Remove rows or columns containing missing values (NaN)
# Focus - Works based on NaN detection

# %%
# Dropna it is used to when total missing data is less than 15%   # You can set Threshold to get more than 50%

titanic_df1 = titanic.dropna()  # Giving in new name so the original data is not impacted
titanic_df1
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# ...                                                        ...     ...   ...
# ...

# %%
titanic.shape
# Out:
# (891, 11)

# %%
titanic_df1.shape
# Out:
# (183, 11)

# %%
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
titanic_df1 = titanic_df1.drop(['Ticket','Fare'], axis=1)  # axis=1 - Means you are dropping columns (axis=0 would mean rows)
titanic_df1.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch Embarked
# PassengerId
# 1                1      0        S
# 2                1      0        C
# 3                0      0        S
# 4                1      0        S
# 5                0      0        S

# %%
# We can create a threshold - we can decide what is the limit in the data and
# what condition should be used to remove the data
# like if the data os greater than the mid value

# %%
half_count = len(titanic)/2
print(half_count)
# Out:
# 445.5

# %%
# We got the mid value
# We can check what value are greater than mid value
titanic.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
titanic = titanic.dropna(thresh=half_count,axis=1)      # Here we have given the threshhold and mentioned type of column
print(titanic.isnull().sum())
titanic.shape
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Embarked      2
# dtype: int64
# (891, 10)

# %%
# Subset -- refers to the specific column(s) to check for missing values (NaN) before dropping rows
# Only rows where embarked is NaN will be dropped
# Other columns can still have NaN values; They are ignored in this operation

titanic_df1 = titanic.dropna(subset = ["Embarked"])
titanic_df1.shape
titanic_df1
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# Logic similar to AND operator (will drop column only when same row from age and embarked should be missing)
# how = any(AND)
titanic_df2 = titanic.dropna(how='all', subset=['Age','Embarked'])
titanic_df2
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# Logic similar to OR operator (missing value either in age or embarked)
# how = any(or)
titanic_df1 = titanic.dropna(how="any", subset=["Age","Embarked"])
titanic_df1.shape
# Out:
# (712, 10)

# %%
print(titanic_df1.isnull().sum())   # duplicate data where nulls are removed
